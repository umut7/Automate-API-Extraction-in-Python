# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-10-04T10:31:55.838Z', 'error_code': 0, 'error_message': None, 'elapsed': 24, 'credit_count': 1, 'notice': None, 'total_count': 9852}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11755, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19762793, 'total_supply': 19762793, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-04T10:31:00.000Z', 'quote': {'USD': {'price': 61270.3017060202, 'volume_24h': 32622794508.055668, 'volume_change_24h': -21.4923, 'percent_change_1h': -0.20234929, 'percent_change_24h': 0.73484339, 'percent_change_7d': -6.59760706, 'percent_change_30d': 8.10476199, 'percent_change_60d': 19.45074403, 'percent_change_90d': 8.09460771, 'market_cap': 1210872289663.624, 'market_cap_dominance': 56.8842, 'fully_diluted_market_cap': 1286676335826.42, 'tvl': None, 'last_updated': '2024-10-04T10:31:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 9376, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120373387.49310343, 'total_supply': 120373387.49310343, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-04T10:30:00.000Z', 'quote': {'USD': {'price': 2374.977811869914, 'volume_24h': 16159640393.312464, 'volume_change_24h': -24.0241, 'percent_change_1h': -0.28073804, 'percent_change_24h': 1.01928307, 'percent_change_7d': -10.29099515, 'percent_change_30d': -1.00542105, 'percent_change_60d': 4.8171298, 'percent_change_90d': -20.91647277, 'market_cap': 285884124435.74005, 'market_cap_dominance': 13.4302, 'fully_diluted_market_cap': 285884124435.74, 'tvl': None, 'last_updated': '2024-10-04T10:30:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 99395, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem', 'fiat-stablecoin'], 'max_supply': None, 'circulating_supply': 119641989887.49706, 'total_supply': 121372645826.72647, 'platform': {'id ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             11755
# 1    1027      Ethereum    ETH      ethereum              9376
# 2     825   Tether USDt   USDT        tether             99395
# 3    1839           BNB    BNB           bnb              2252
# 4    5426        Solana    SOL        solana               749
# 5    3408          USDC   USDC      usd-coin             22287
# 6      52           XRP    XRP           xrp              1400
# 7      74      Dogecoin   DOGE      dogecoin              1076
# 8    1958          TRON    TRX          tron              1043
# 9   11419       Toncoin    TON       toncoin               569
# 10   2010       Cardano    ADA       cardano              1261
# 11   5805     Avalanche   AVAX     avalanche               784
# 12   5994     Shiba Inu   SHIB     shiba-inu               882
# 13   1975     Chainlink   LINK     chainlink              1852
# 14   1831  Bitcoin Cash    BCH  bitcoin-cash               930
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2017-09-13T00:00:00.000Z
# 9   2021-08-26T13:40:22.000Z
# 10  2017-10-01T00:00:00.000Z
# 11  2020-07-13T00:00:00.000Z
# 12  2020-08-01T00:00:00.000Z
# 13  2017-09-20T00:00:00.000Z
# 14  2017-07-23T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [stablecoin, asset-backed-stablecoin, avalanch...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 7   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 8   [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 9   [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...           NaN
# 10  [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 11  [defi, smart-contracts, three-arrows-capital-p...  7.157487e+08
# 12      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 13  [platform, defi, oracles, smart-contracts, sub...           NaN
# 14  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
#
#     circulating_supply  total_supply  ...  quote.USD.market_cap_dominance  \
# 0         1.976279e+07  1.976279e+07  ...                         56.8842
# 1         1.203734e+08  1.203734e+08  ...                         13.4302
# 2         1.196420e+11  1.213726e+11  ...                          5.6193
# 3         1.459326e+08  1.459326e+08  ...                          3.7792
# 4         4.684844e+08  5.858259e+08  ...                          3.0756
# 5         3.557687e+10  3.557687e+10  ...                          1.6713
# 6         5.656404e+10  9.998716e+10  ...                          1.3899
# 7         1.462249e+11  1.462249e+11  ...                          0.7391
# 8         8.659154e+10  8.659157e+10  ...                          0.6399
# 9         2.533304e+09  5.112546e+09  ...                          0.6375
# 10        3.495641e+10  4.499514e+10  ...                          0.5762
# 11        4.064050e+08  4.464081e+08  ...                          0.4853
# 12        5.892675e+14  5.895184e+14  ...                          0.4681
# 13        6.268500e+08  1.000000e+09  ...                          0.3241
# 14        1.976956e+07  1.976956e+07  ...                          0.2976
#
#     quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                         1.286676e+12           None
# 1                         2.858841e+11           None
# 2                         1.213455e+11           None
# 3                         8.044743e+10           None
# 4                         8.186785e+10           None
# 5                         3.557565e+10           None
# 6                         5.230549e+10           None
# 7                         1.573223e+10           None
# 8                         1.362194e+10           None
# 9                         2.738596e+10           None
# 10                        1.578878e+10           None
# 11                        1.819237e+10           None
# 12                        9.967629e+09           None
# 13                        1.100677e+10           None
# 14                        6.728469e+09           None
#
#       quote.USD.last_updated  platform.id platform.name platform.symbol  \
# 0   2024-10-04T10:31:00.000Z          NaN           NaN             NaN
# 1   2024-10-04T10:30:00.000Z          NaN           NaN             NaN
# 2   2024-10-04T10:30:00.000Z       1027.0      Ethereum             ETH
# 3   2024-10-04T10:30:00.000Z          NaN           NaN             NaN
# 4   2024-10-04T10:30:00.000Z          NaN           NaN             NaN
# 5   2024-10-04T10:30:00.000Z       1027.0      Ethereum             ETH
# 6   2024-10-04T10:31:00.000Z          NaN           NaN             NaN
# 7   2024-10-04T10:31:00.000Z          NaN           NaN             NaN
# 8   2024-10-04T10:30:00.000Z          NaN           NaN             NaN
# 9   2024-10-04T10:30:00.000Z          NaN           NaN             NaN
# 10  2024-10-04T10:30:00.000Z          NaN           NaN             NaN
# 11  2024-10-04T10:30:00.000Z          NaN           NaN             NaN
# 12  2024-10-04T10:30:00.000Z       1027.0      Ethereum             ETH
# 13  2024-10-04T10:30:00.000Z       1027.0      Ethereum             ETH
# 14  2024-10-04T10:30:00.000Z          NaN           NaN             NaN
#
#     platform.slug                      platform.token_address  \
# 0             NaN                                         NaN
# 1             NaN                                         NaN
# 2        ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3             NaN                                         NaN
# 4             NaN                                         NaN
# 5        ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6             NaN                                         NaN
# 7             NaN                                         NaN
# 8             NaN                                         NaN
# 9             NaN                                         NaN
# 10            NaN                                         NaN
# 11            NaN                                         NaN
# 12       ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 13       ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 14            NaN                                         NaN
#
#                     timestamp
# 0  2024-10-04 13:31:57.386045
# 1  2024-10-04 13:31:57.386045
# 2  2024-10-04 13:31:57.386045
# 3  2024-10-04 13:31:57.386045
# 4  2024-10-04 13:31:57.386045
# 5  2024-10-04 13:31:57.386045
# 6  2024-10-04 13:31:57.386045
# 7  2024-10-04 13:31:57.386045
# 8  2024-10-04 13:31:57.386045
# 9  2024-10-04 13:31:57.386045
# 10 2024-10-04 13:31:57.386045
# 11 2024-10-04 13:31:57.386045
# 12 2024-10-04 13:31:57.386045
# 13 2024-10-04 13:31:57.386045
# 14 2024-10-04 13:31:57.386045
#
# [15 rows x 37 columns]

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': 'd1ce39ba-9569-4d27-b07e-2196a7ca2064',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    
    
    df2 = pd.json_normalize(data['data'])
    df2['timestamp'] = pd.to_datetime('now')
    df = df.append(df2)

# %%
import os
from time import time
from time import sleep

for i in range(1000):
    api_runner()
    print('API Runner completed successfully.')
    sleep(60)
exit()
# Out:
# {'status': {'timestamp': '2024-10-04T10:31:58.273Z', 'error_code': 0, 'error_message': None, 'elapsed': 8, 'credit_count': 1, 'notice': None, 'total_count': 9852}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11755, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19762793, 'total_supply': 19762793, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-04T10:31:00.000Z', 'quote': {'USD': {'price': 61270.3017060202, 'volume_24h': 32622794508.055668, 'volume_change_24h': -21.4923, 'percent_change_1h': -0.20234929, 'percent_change_24h': 0.73484339, 'percent_change_7d': -6.59760706, 'percent_change_30d': 8.10476199, 'percent_change_60d': 19.45074403, 'percent_change_90d': 8.09460771, 'market_cap': 1210872289663.624, 'market_cap_dominance': 56.8842, 'fully_diluted_market_cap': 1286676335826.42, 'tvl': None, 'last_updated': '2024-10-04T10:31:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 9376, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120373387.49310343, 'total_supply': 120373387.49310343, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2024-10-04T10:30:00.000Z', 'quote': {'USD': {'price': 2374.977811869914, 'volume_24h': 16159640393.312464, 'volume_change_24h': -24.0241, 'percent_change_1h': -0.28073804, 'percent_change_24h': 1.01928307, 'percent_change_7d': -10.29099515, 'percent_change_30d': -1.00542105, 'percent_change_60d': 4.8171298, 'percent_change_90d': -20.91647277, 'market_cap': 285884124435.74005, 'market_cap_dominance': 13.4302, 'fully_diluted_market_cap': 285884124435.74, 'tvl': None, 'last_updated': '2024-10-04T10:30:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 99395, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem', 'fiat-stablecoin'], 'max_supply': None, 'circulating_supply': 119641989887.49706, 'total_supply': 121372645826.72647, 'platform': {'id' ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16888\1724210955.py in ?()
#       2 from time import time
#       3 from time import sleep
#       4
#       5 for i in range(1000):
# ----> 6     api_runner()
#       7     print('API Runner completed successfully.')
#       8     sleep(60)
#       9 exit()
#
# ~\AppData\Local\Temp\ipykernel_16888\3039421599.py in ?()
#      24
#      25
#      26     df2 = pd.json_normalize(data['data'])
#      27     df2['timestamp'] = pd.to_datetime('now')
# ---> 28     df = df.append(df2)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df72 = pd.read_csv(r'path')
df72

# %%
df

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3

# %%
df4 = df3.stack()
df4

# %%
type(df4)

# %%
df5 = df4.to_frame(name='values')
df5

# %%
df5.count()

# %%
index = pd.Index(range(90))

df6 = df5.set_index(index)
df6

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
df7

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
